# %%
# %pylab inline
import pytry
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import neuron_bee

for n_neurons in range(10,110,10):
    for i in range(5):
        neuron_bee.GatherDataTrial().run(Ki=1.0, pose_var=.4, n_neurons=n_neurons,
            T=2.0, data_format='npz', data_dir="data_10_to_100_neurons")
# Out:
# running GatherDataTrial#20170706-182606-900b6287
# Building finished in 0:00:01.
# //anaconda/envs/robobee/lib/python3.5/site-packages/scipy/integrate/_ode.py:1035: UserWarning: dopri5: step size becomes too small
#   self.messages.get(idid, 'Unexpected idid=%s' % idid))
# Simulating finished in 0:00:33.
# learning_rate = 0.0001
# radius_scaling = 1.0
# dt = 0.001
# T = 2.0
# use_pif = False
# seed = 1
# low_intercept = -1.0
# oracle = False
# dpose_var = 0.0
# ctrl_filename = 'gather6-hover.npz'
# n_neurons = 10
# angle = 0.0
# reg = 0.1
# Ki = 1.0
# velocity = 0.0
# backend = 'nengo'
# pose_var = 0.4
# pif_u = array([[  7.24853008e-01,   1.38385922e-02,   1.14581574e+08,
#          -5.80056921e-04],
#        [  7.33258909e-01,   3.36258919e-02,   1.14581574e+08,
#          -1.15784439e-03],
#        [  7.43311772e-01,   4.53413871e-02,   1.14581574e+08,
#          -1.73265419e-03],
#        ...,
#        [ -6.14999193e+00,  -2.77336502e+01,   1.14581574e+08,
#           2.93670582e-01],
#        [ -6.16854169e+00,  -2.79475959e+01,   1.14581574e+08,
#          -1.69631741e-01],
#        [ -6.14623623e+00,  -2.71779622e+01,   1.14581574e+08,
#          -5.23226419e-01]])
# solver_error = array([  1.09270325e-01,   1.41815332e-01,   1.56850937e+07,
#          3.43290749e-03])
# u = array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [ -1.37081417e-01,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  9.58343903e-01,   3.79251441e-01,   7.76480112e+07,
#           7.30785467e-03],
#        ...,
#        [  5.09839789e+00,   6.39226948e-01,   5.80036966e+08,
#          -2.38437738e-02],
#        [  1.49455369e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  4.45242221e+00,  -1.58939698e-01,   4.73153690e+08,
#          -2.91971392e-02]])
# x = array([[  2.03889969e-02,   1.00524880e+00,   4.66027053e+02, ...,
#           3.12886740e-02,  -1.24463606e-03,   1.56150496e-02],
#        [  4.16126703e-01,   8.40675472e-01,   2.85353422e+02, ...,
#           4.70195891e-02,   6.60911651e-04,   8.88595527e-03],
#        [  5.34400179e-01,   1.73881569e-01,  -5.64326181e+01, ...,
#           3.75718615e-02,   1.56583174e-03,   1.71292819e-02],
#        ...,
#        [ -2.01910015e+00,   3.65251743e+00,  -1.17839354e+03, ...,
#           3.08492346e+00,  -1.38075236e+00,   7.11271256e+00],
#        [ -2.64770870e+00,   1.98269105e+00,  -4.48016972e+00, ...,
#           3.09203913e+00,  -1.35976885e+00,   7.08749907e+00],
#        [ -1.89802228e+00,   1.56552417e+00,   1.41833501e+03, ...,
#           3.00415912e+00,  -1.28145606e+00,   7.05043308e+00]])
# running GatherDataTrial#20170706-182639-039538ee
# Building finished in 0:00:01.
# Simulating finished in 0:00:33.
# learning_rate = 0.0001
# radius_scaling = 1.0
# dt = 0.001
# T = 2.0
# use_pif = False
# seed = 1
# low_intercept = -1.0
# oracle = False
# dpose_var = 0.0
# ctrl_filename = 'gather6-hover.npz'
# n_neurons = 10
# angle = 0.0
# reg = 0.1
# Ki = 1.0
# velocity = 0.0
# backend = 'nengo'
# pose_var = 0.4
# pif_u = array([[  7.24853008e-01,   1.38385922e-02,   1.14581574e+08,
#          -5.80056921e-04],
#        [  7.33258909e-01,   3.36258919e-02,   1.14581574e+08,
#          -1.15784439e-03],
#        [  7.43311772e-01,   4.53413871e-02,   1.14581574e+08,
#          -1.73265419e-03],
#        ...,
#        [ -6.14999193e+00,  -2.77336502e+01,   1.14581574e+08,
#           2.93670582e-01],
#        [ -6.16854169e+00,  -2.79475959e+01,   1.14581574e+08,
#          -1.69631741e-01],
#        [ -6.14623623e+00,  -2.71779622e+01,   1.14581574e+08,
#          -5.23226419e-01]])
# solver_error = array([  1.09270325e-01,   1.41815332e-01,   1.56850937e+07,
#          3.43290749e-03])
# u = array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [ -1.37081417e-01,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  9.58343903e-01,   3.79251441e-01,   7.76480112e+07,
#           7.30785467e-03],
#        ...,
#        [  5.09839789e+00,   6.39226948e-01,   5.80036966e+08,
#          -2.38437738e-02],
#        [  1.49455369e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  4.45242221e+00,  -1.58939698e-01,   4.73153690e+08,
#          -2.91971392e-02]])
# x = array([[  2.03889969e-02,   1.00524880e+00,   4.66027053e+02, ...,
#           3.12886740e-02,  -1.24463606e-03,   1.56150496e-02],
#        [  4.16126703e-01,   8.40675472e-01,   2.85353422e+02, ...,
#           4.70195891e-02,   6.60911651e-04,   8.88595527e-03],
#        [  5.34400179e-01,   1.73881569e-01,  -5.64326181e+01, ...,
#           3.75718615e-02,   1.56583174e-03,   1.71292819e-02],
#        ...,
#        [ -2.01910015e+00,   3.65251743e+00,  -1.17839354e+03, ...,
#           3.08492346e+00,  -1.38075236e+00,   7.11271256e+00],
#        [ -2.64770870e+00,   1.98269105e+00,  -4.48016972e+00, ...,
#           3.09203913e+00,  -1.35976885e+00,   7.08749907e+00],
#        [ -1.89802228e+00,   1.56552417e+00,   1.41833501e+03, ...,
#           3.00415912e+00,  -1.28145606e+00,   7.05043308e+00]])
# running GatherDataTrial#20170706-182712-a3022e38
# Building finished in 0:00:01.
# Simulating finished in 0:00:32.
# learning_rate = 0.0001
# radius_scaling = 1.0
# dt = 0.001
# T = 2.0
# use_pif = False
# seed = 1
# low_intercept = -1.0
# oracle = False
# dpose_var = 0.0
# ctrl_filename = 'gather6-hover.npz'
# n_neurons = 10
# angle = 0.0
# reg = 0.1
# Ki = 1.0
# velocity = 0.0
# backend = 'nengo'
# pose_var = 0.4
# pif_u = array([[  7.24853008e-01,   1.38385922e-02,   1.14581574e+08,
#          -5.80056921e-04],
#        [  7.33258909e-01,   3.36258919e-02,   1.14581574e+08,
#          -1.15784439e-03],
#        [  7.43311772e-01,   4.53413871e-02,   1.14581574e+08,
#          -1.73265419e-03],
#        ...,
#        [ -6.14999193e+00,  -2.77336502e+01,   1.14581574e+08,
#           2.93670582e-01],
#        [ -6.16854169e+00,  -2.79475959e+01,   1.14581574e+08,
#          -1.69631741e-01],
#        [ -6.14623623e+00,  -2.71779622e+01,   1.14581574e+08,
#          -5.23226419e-01]])
# solver_error = array([  1.09270325e-01,   1.41815332e-01,   1.56850937e+07,
#          3.43290749e-03])
# u = array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [ -1.37081417e-01,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  9.58343903e-01,   3.79251441e-01,   7.76480112e+07,
#           7.30785467e-03],
#        ...,
#        [  5.09839789e+00,   6.39226948e-01,   5.80036966e+08,
#          -2.38437738e-02],
#        [  1.49455369e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  4.45242221e+00,  -1.58939698e-01,   4.73153690e+08,
#          -2.91971392e-02]])
# x = array([[  2.03889969e-02,   1.00524880e+00,   4.66027053e+02, ...,
#           3.12886740e-02,  -1.24463606e-03,   1.56150496e-02],
#        [  4.16126703e-01,   8.40675472e-01,   2.85353422e+02, ...,
#           4.70195891e-02,   6.60911651e-04,   8.88595527e-03],
#        [  5.34400179e-01,   1.73881569e-01,  -5.64326181e+01, ...,
#           3.75718615e-02,   1.56583174e-03,   1.71292819e-02],
#        ...,
#        [ -2.01910015e+00,   3.65251743e+00,  -1.17839354e+03, ...,
#           3.08492346e+00,  -1.38075236e+00,   7.11271256e+00],
#        [ -2.64770870e+00,   1.98269105e+00,  -4.48016972e+00, ...,
#           3.09203913e+00,  -1.35976885e+00,   7.08749907e+00],
#        [ -1.89802228e+00,   1.56552417e+00,   1.41833501e+03, ...,
#           3.00415912e+00,  -1.28145606e+00,   7.05043308e+00]])
# running GatherDataTrial#20170706-182744-4a4a2cd3
# Building finished in 0:00:01.
# Simulating finished in 0:00:32.
# learning_rate = 0.0001
# radius_scaling = 1.0
# dt = 0.001
# T = 2.0
# use_pif = False
# seed = 1
# low_intercept = -1.0
# oracle = False
# dpose_var = 0.0
# ctrl_filename = 'gather6-hover.npz'
# n_neurons = 10
# angle = 0.0
# reg = 0.1
# Ki = 1.0
# velocity = 0.0
# backend = 'nengo'
# pose_var = 0.4
# pif_u = array([[  7.24853008e-01,   1.38385922e-02,   1.14581574e+08,
#          -5.80056921e-04],
#        [  7.33258909e-01,   3.36258919e-02,   1.14581574e+08,
#          -1.15784439e-03],
#        [  7.43311772e-01,   4.53413871e-02,   1.14581574e+08,
#          -1.73265419e-03],
#        ...,
#        [ -5.05066352e+00,   2.09355678e+01,   1.14581574e+08,
#          -5.74945497e+00],
#        [ -5.06898097e+00,   2.11079521e+01,   1.14581574e+08,
#          -5.63571020e+00],
#        [ -5.05361080e+00,   2.11520743e+01,   1.14581574e+08,
#          -5.49415911e+00]])
# solver_error = array([  1.09270325e-01,   1.41815332e-01,   1.56850937e+07,
#          3.43290749e-03])
# u = array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [ -1.37081417e-01,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  9.58343903e-01,   3.79251441e-01,   7.76480112e+07,
#           7.30785467e-03],
#        ...,
#        [  4.34153567e+00,  -5.43405919e-01,   4.13577402e+08,
#           2.60801828e-02],
#        [  1.46348259e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  4.13641782e+00,  -5.43405919e-01,   4.13577402e+08,
#           2.60801828e-02]])
# x = array([[  2.03889969e-02,   1.00524880e+00,   4.66027053e+02, ...,
#           3.12886740e-02,  -1.24463606e-03,   1.56150496e-02],
#        [  4.16126703e-01,   8.40675472e-01,   2.85353422e+02, ...,
#           4.70195891e-02,   6.60911651e-04,   8.88595527e-03],
#        [  5.34400179e-01,   1.73881569e-01,  -5.64326181e+01, ...,
#           3.75718615e-02,   1.56583174e-03,   1.71292819e-02],
#        ...,
#        [ -2.01277564e+00,  -9.96653280e-01,  -1.28725852e+03, ...,
#           3.28932505e+00,  -2.35240743e+00,   4.58477521e+00],
#        [ -2.66288628e+00,   1.11994566e-02,   5.77858663e+01, ...,
#           3.29373039e+00,  -2.34891080e+00,   4.59067738e+00],
#        [ -1.85449112e+00,   1.59516372e+00,   1.46705745e+03, ...,
#           3.24343609e+00,  -2.26131175e+00,   4.50254654e+00]])
# running GatherDataTrial#20170706-182816-818d7ba9
# Building finished in 0:00:01.
# Simulating finished in 0:00:32.
# learning_rate = 0.0001
# radius_scaling = 1.0
# dt = 0.001
# T = 2.0
# use_pif = False
# seed = 1
# low_intercept = -1.0
# oracle = False
# dpose_var = 0.0
# ctrl_filename = 'gather6-hover.npz'
# n_neurons = 10
# angle = 0.0
# reg = 0.1
# Ki = 1.0
# velocity = 0.0
# backend = 'nengo'
# pose_var = 0.4
# pif_u = array([[  7.24853008e-01,   1.38385922e-02,   1.14581574e+08,
#          -5.80056921e-04],
#        [  7.33258909e-01,   3.36258919e-02,   1.14581574e+08,
#          -1.15784439e-03],
#        [  7.43311772e-01,   4.53413871e-02,   1.14581574e+08,
#          -1.73265419e-03],
#        ...,
#        [ -8.90749982e+00,   4.25030435e+01,   1.14581574e+08,
#           2.44665457e+00],
#        [ -8.90056559e+00,   4.29394316e+01,   1.14581574e+08,
#           2.39500957e+00],
#        [ -8.91087280e+00,   4.31967658e+01,   1.14581574e+08,
#           2.40309193e+00]])
# solver_error = array([  1.09270325e-01,   1.41815332e-01,   1.56850937e+07,
#          3.43290749e-03])
# u = array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [ -1.37081417e-01,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  9.58343903e-01,   3.79251441e-01,   7.76480112e+07,
#           7.30785467e-03],
#        ...,
#        [  2.30804868e+00,   9.84964894e-01,   1.61463880e+08,
#          -4.43160783e-04],
#        [  3.77049540e+00,   5.05410182e-02,   3.35713049e+08,
#          -2.51257820e-02],
#        [  2.62595537e+00,   9.84964894e-01,   1.61463880e+08,
#          -4.43160783e-04]])
# x = array([[  2.03889969e-02,   1.00524880e+00,   4.66027053e+02, ...,
#           3.12886740e-02,  -1.24463606e-03,   1.56150496e-02],
#        [  4.16126703e-01,   8.40675472e-01,   2.85353422e+02, ...,
#           4.70195891e-02,   6.60911651e-04,   8.88595527e-03],
#        [  5.34400179e-01,   1.73881569e-01,  -5.64326181e+01, ...,
#           3.75718615e-02,   1.56583174e-03,   1.71292819e-02],
#        ...,
#        [ -1.82909233e+00,   3.50924064e+00,  -9.70142248e+02, ...,
#           3.55008189e+00,   1.91538080e+00,   5.64928246e+00],
#        [ -2.24670848e+00,   1.72798819e+00,   1.74483163e+02, ...,
#           3.55193320e+00,   1.91060963e+00,   5.64116868e+00],
#        [ -1.50417833e+00,   1.59237607e+00,   1.25276514e+03, ...,
#           3.56518650e+00,   1.89482141e+00,   5.52660344e+00]])
# running GatherDataTrial#20170706-182848-e0d0b3eb
# Building finished in 0:00:01.
# Simulating finished in 0:00:30.
# learning_rate = 0.0001
# radius_scaling = 1.0
# dt = 0.001
# T = 2.0
# use_pif = False
# seed = 1
# low_intercept = -1.0
# oracle = False
# dpose_var = 0.0
# ctrl_filename = 'gather6-hover.npz'
# n_neurons = 20
# angle = 0.0
# reg = 0.1
# Ki = 1.0
# velocity = 0.0
# backend = 'nengo'
# pose_var = 0.4
# pif_u = array([[  7.24853008e-01,   1.38385922e-02,   1.14581574e+08,
#          -5.80056921e-04],
#        [  7.33258909e-01,   3.36258919e-02,   1.14581574e+08,
#          -1.15784439e-03],
#        [  7.41013177e-01,   3.28340331e-02,   1.14581574e+08,
#          -4.51703563e-04],
#        ...,
#        [ -7.38663382e+00,   2.36081172e+01,   1.14581574e+08,
#          -2.25537020e+00],
#        [ -7.38690193e+00,   2.36600916e+01,   1.14581574e+08,
#          -2.26865262e+00],
#        [ -7.37902885e+00,   2.36021868e+01,   1.14581574e+08,
#          -2.27457543e+00]])
# solver_error = array([  6.10006678e-02,   1.00787597e-01,   6.75032127e+06,
#          3.35272460e-03])
# u = array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  5.95416687e-02,   2.03123562e-01,   3.03070017e+07,
#          -7.90430426e-03],
#        [  1.66931401e+00,  -4.01885111e-01,   1.94169642e+08,
#           1.09061673e-03],
#        ...,
#        [  2.67051654e+00,  -7.04933528e-01,   2.19227582e+08,
#           5.86955694e-04],
#        [  1.98134513e+00,   6.96154795e-02,   5.48839982e+07,
#          -9.62263169e-03],
#        [  1.65278148e+00,   8.01784260e-01,   3.26655467e+07,
#           3.13054481e-03]])
# x = array([[  2.03889969e-02,   1.00524880e+00,   4.66027053e+02, ...,
#           3.12886740e-02,  -1.24463606e-03,   1.56150496e-02],
#        [  4.16126703e-01,   8.40675472e-01,   2.85353422e+02, ...,
#           4.70195891e-02,   6.60911651e-04,   8.88595527e-03],
#        [  5.34182656e-01,   1.73579752e-01,  -5.74889837e+01, ...,
#           3.75271438e-02,   1.58397694e-03,   1.71179897e-02],
#        ...,
#        [ -1.71476036e+00,  -1.06309211e+00,  -9.69700556e+02, ...,
#          -1.81847717e-01,  -2.65670468e+00,   5.12391051e+00],
#        [ -2.11385616e+00,  -3.91865044e-01,   2.10213882e+02, ...,
#          -1.74962128e-01,  -2.65548744e+00,   5.14230634e+00],
#        [ -1.34801490e+00,   1.20320509e+00,   1.24430186e+03, ...,
#          -1.58651566e-01,  -2.65947757e+00,   5.11498861e+00]])
# running GatherDataTrial#20170706-182918-5071a4a5
# Building finished in 0:00:01.
# Simulating finished in 0:00:28.
# learning_rate = 0.0001
# radius_scaling = 1.0
# dt = 0.001
# T = 2.0
# use_pif = False
# seed = 1
# low_intercept = -1.0
# oracle = False
# dpose_var = 0.0
# ctrl_filename = 'gather6-hover.npz'
# n_neurons = 20
# angle = 0.0
# reg = 0.1
# Ki = 1.0
# velocity = 0.0
# backend = 'nengo'
# pose_var = 0.4
# pif_u = array([[  7.24853008e-01,   1.38385922e-02,   1.14581574e+08,
#          -5.80056921e-04],
#        [  7.33258909e-01,   3.36258919e-02,   1.14581574e+08,
#          -1.15784439e-03],
#        [  7.41013177e-01,   3.28340331e-02,   1.14581574e+08,
#          -4.51703563e-04],
#        ...,
#        [ -1.06247866e+00,   8.88299515e-01,   1.14581574e+08,
#           5.04055191e-02],
#        [ -1.06555644e+00,   8.40690836e-01,   1.14581574e+08,
#           5.04804011e-02],
#        [ -1.06227850e+00,   8.29729872e-01,   1.14581574e+08,
#           4.89218274e-02]])
# solver_error = array([  6.10006678e-02,   1.00787597e-01,   6.75032127e+06,
#          3.35272460e-03])
# u = array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  5.95416687e-02,   2.03123562e-01,   3.03070017e+07,
#          -7.90430426e-03],
#        [  1.66931401e+00,  -4.01885111e-01,   1.94169642e+08,
#           1.09061673e-03],
#        ...,
#        [  1.00249257e+00,   1.38930331e-01,   1.47355261e+08,
#          -1.97787899e-03],
#        [  4.64860053e-01,  -2.28079352e-01,   5.83046635e+07,
#           8.74393852e-03],
#        [  9.66114498e-01,  -1.69262455e+00,   1.81956747e+08,
#          -5.71038323e-03]])
# x = array([[  2.03889969e-02,   1.00524880e+00,   4.66027053e+02, ...,
#           3.12886740e-02,  -1.24463606e-03,   1.56150496e-02],
#        [  4.16126703e-01,   8.40675472e-01,   2.85353422e+02, ...,
#           4.70195891e-02,   6.60911651e-04,   8.88595527e-03],
#        [  5.34182656e-01,   1.73579752e-01,  -5.74889837e+01, ...,
#           3.75271438e-02,   1.58397694e-03,   1.71179897e-02],
#        ...,
#        [ -4.41103008e-01,  -8.84321989e-01,  -3.44920148e+02, ...,
#           4.87188009e-01,   1.31760390e-01,   6.19947014e-02],
#        [ -6.49719375e-01,  -2.64330786e-01,  -4.94447262e+01, ...,
#           4.91658464e-01,   1.33556097e-01,   7.60028919e-02],
#        [ -5.00293141e-01,   3.96402578e-01,   3.31457926e+02, ...,
#           5.01103179e-01,   1.36941068e-01,   1.01867661e-01]])
# running GatherDataTrial#20170706-182945-f719acbe
# Building finished in 0:00:01.
# Simulating finished in 0:00:28.
# learning_rate = 0.0001
# radius_scaling = 1.0
# dt = 0.001
# T = 2.0
# use_pif = False
# seed = 1
# low_intercept = -1.0
# oracle = False
# dpose_var = 0.0
# ctrl_filename = 'gather6-hover.npz'
# n_neurons = 20
# angle = 0.0
# reg = 0.1
# Ki = 1.0
# velocity = 0.0
# backend = 'nengo'
# pose_var = 0.4
# pif_u = array([[  7.24853008e-01,   1.38385922e-02,   1.14581574e+08,
#          -5.80056921e-04],
#        [  7.33258909e-01,   3.36258919e-02,   1.14581574e+08,
#          -1.15784439e-03],
#        [  7.41013177e-01,   3.28340331e-02,   1.14581574e+08,
#          -4.51703563e-04],
#        ...,
#        [ -1.06247866e+00,   8.88299515e-01,   1.14581574e+08,
#           5.04055191e-02],
#        [ -1.06555644e+00,   8.40690836e-01,   1.14581574e+08,
#           5.04804011e-02],
#        [ -1.06227850e+00,   8.29729872e-01,   1.14581574e+08,
#           4.89218274e-02]])
# solver_error = array([  6.10006678e-02,   1.00787597e-01,   6.75032127e+06,
#          3.35272460e-03])
# u = array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  5.95416687e-02,   2.03123562e-01,   3.03070017e+07,
#          -7.90430426e-03],
#        [  1.66931401e+00,  -4.01885111e-01,   1.94169642e+08,
#           1.09061673e-03],
#        ...,
#        [  1.00249257e+00,   1.38930331e-01,   1.47355261e+08,
#          -1.97787899e-03],
#        [  4.64860053e-01,  -2.28079352e-01,   5.83046635e+07,
#           8.74393852e-03],
#        [  9.66114498e-01,  -1.69262455e+00,   1.81956747e+08,
#          -5.71038323e-03]])
# x = array([[  2.03889969e-02,   1.00524880e+00,   4.66027053e+02, ...,
#           3.12886740e-02,  -1.24463606e-03,   1.56150496e-02],
#        [  4.16126703e-01,   8.40675472e-01,   2.85353422e+02, ...,
#           4.70195891e-02,   6.60911651e-04,   8.88595527e-03],
#        [  5.34182656e-01,   1.73579752e-01,  -5.74889837e+01, ...,
#           3.75271438e-02,   1.58397694e-03,   1.71179897e-02],
#        ...,
#        [ -4.41103008e-01,  -8.84321989e-01,  -3.44920148e+02, ...,
#           4.87188009e-01,   1.31760390e-01,   6.19947014e-02],
#        [ -6.49719375e-01,  -2.64330786e-01,  -4.94447262e+01, ...,
#           4.91658464e-01,   1.33556097e-01,   7.60028919e-02],
#        [ -5.00293141e-01,   3.96402578e-01,   3.31457926e+02, ...,
#           5.01103179e-01,   1.36941068e-01,   1.01867661e-01]])
# running GatherDataTrial#20170706-183013-109fe9b4
# Building finished in 0:00:01.
# Simulating finished in 0:00:28.
# learning_rate = 0.0001
# radius_scaling = 1.0
# dt = 0.001
# T = 2.0
# use_pif = False
# seed = 1
# low_intercept = -1.0
# oracle = False
# dpose_var = 0.0
# ctrl_filename = 'gather6-hover.npz'
# n_neurons = 20
# angle = 0.0
# reg = 0.1
# Ki = 1.0
# velocity = 0.0
# backend = 'nengo'
# pose_var = 0.4
# pif_u = array([[  7.24853008e-01,   1.38385922e-02,   1.14581574e+08,
#          -5.80056921e-04],
#        [  7.33258909e-01,   3.36258919e-02,   1.14581574e+08,
#          -1.15784439e-03],
#        [  7.41013177e-01,   3.28340331e-02,   1.14581574e+08,
#          -4.51703563e-04],
#        ...,
#        [ -1.09535729e+00,   2.48430313e-01,   1.14581574e+08,
#           6.36089501e-02],
#        [ -1.09180617e+00,   2.12541987e-01,   1.14581574e+08,
#           6.34333623e-02],
#        [ -1.09621592e+00,   2.07400671e-01,   1.14581574e+08,
#           6.40599456e-02]])
# solver_error = array([  6.10006678e-02,   1.00787597e-01,   6.75032127e+06,
#          3.35272460e-03])
# u = array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  5.95416687e-02,   2.03123562e-01,   3.03070017e+07,
#          -7.90430426e-03],
#        [  1.66931401e+00,  -4.01885111e-01,   1.94169642e+08,
#           1.09061673e-03],
#        ...,
#        [  4.22217350e-01,  -1.82606110e-01,   5.14413493e+07,
#          -4.09751653e-04],
#        [  1.10114529e+00,  -5.31197198e-01,   1.52312571e+08,
#          -5.42251894e-03],
#        [  4.78008323e-01,  -9.68409819e-01,   7.44943811e+07,
#           1.33399143e-03]])
# x = array([[  2.03889969e-02,   1.00524880e+00,   4.66027053e+02, ...,
#           3.12886740e-02,  -1.24463606e-03,   1.56150496e-02],
#        [  4.16126703e-01,   8.40675472e-01,   2.85353422e+02, ...,
#           4.70195891e-02,   6.60911651e-04,   8.88595527e-03],
#        [  5.34182656e-01,   1.73579752e-01,  -5.74889837e+01, ...,
#           3.75271438e-02,   1.58397694e-03,   1.71179897e-02],
#        ...,
#        [ -1.88778838e-01,  -7.96386604e-01,  -3.80364959e+02, ...,
#           3.22333816e-01,  -9.84742513e-02,   1.27711894e-02],
#        [ -4.69168029e-01,  -6.65505471e-01,  -1.51502619e+02, ...,
#           3.17929152e-01,  -9.89869001e-02,   8.15099208e-03],
#        [ -4.60995727e-01,  -3.21307247e-02,   1.73249912e+02, ...,
#           3.28509916e-01,  -9.84404810e-02,   2.14863378e-02]])
# running GatherDataTrial#20170706-183041-8c6b3e1c
# Building finished in 0:00:01.
# Simulating finished in 0:00:26.
# learning_rate = 0.0001
# radius_scaling = 1.0
# dt = 0.001
# T = 2.0
# use_pif = False
# seed = 1
# low_intercept = -1.0
# oracle = False
# dpose_var = 0.0
# ctrl_filename = 'gather6-hover.npz'
# n_neurons = 20
# angle = 0.0
# reg = 0.1
# Ki = 1.0
# velocity = 0.0
# backend = 'nengo'
# pose_var = 0.4
# pif_u = array([[  7.24853008e-01,   1.38385922e-02,   1.14581574e+08,
#          -5.80056921e-04],
#        [  7.33258909e-01,   3.36258919e-02,   1.14581574e+08,
#          -1.15784439e-03],
#        [  7.41013177e-01,   3.28340331e-02,   1.14581574e+08,
#          -4.51703563e-04],
#        ...,
#        [ -1.09535729e+00,   2.48430313e-01,   1.14581574e+08,
#           6.36089501e-02],
#        [ -1.09180617e+00,   2.12541987e-01,   1.14581574e+08,
#           6.34333623e-02],
#        [ -1.09621592e+00,   2.07400671e-01,   1.14581574e+08,
#           6.40599456e-02]])
# solver_error = array([  6.10006678e-02,   1.00787597e-01,   6.75032127e+06,
#          3.35272460e-03])
# u = array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           0.00000000e+00],
#        [  5.95416687e-02,   2.03123562e-01,   3.03070017e+07,
#          -7.90430426e-03],
#        [  1.66931401e+00,  -4.01885111e-01,   1.94169642e+08,
#           1.09061673e-03],
#        ...,
#        [  4.22217350e-01,  -1.82606110e-01,   5.14413493e+07,
#          -4.09751653e-04],
#        [  1.10114529e+00,  -5.31197198e-01,   1.52312571e+08,
#          -5.42251894e-03],
#        [  4.78008323e-01,  -9.68409819e-01,   7.44943811e+07,
#           1.33399143e-03]])
# x = array([[  2.03889969e-02,   1.00524880e+00,   4.66027053e+02, ...,
#           3.12886740e-02,  -1.24463606e-03,   1.56150496e-02],
#        [  4.16126703e-01,   8.40675472e-01,   2.85353422e+02, ...,
#           4.70195891e-02,   6.60911651e-04,   8.88595527e-03],
#        [  5.34182656e-01,   1.73579752e-01,  -5.74889837e+01, ...,
#           3.75271438e-02,   1.58397694e-03,   1.71179897e-02],
#        ...,
#        [ -1.88778838e-01,  -7.96386604e-01,  -3.80364959e+02, ...,
#           3.22333816e-01,  -9.84742513e-02,   1.27711894e-02],
#        [ -4.69168029e-01,  -6.65505471e-01,  -1.51502619e+02, ...,
#           3.17929152e-01,  -9.89869001e-02,   8.15099208e-03],
#        [ -4.60995727e-01,  -3.21307247e-02,   1.73249912e+02, ...,
#           3.28509916e-01,  -9.84404810e-02,   2.14863378e-02]])
# running GatherDataTrial#20170706-183106-5719b39c
# Building finished in 0:00:01.
# Simulating finished in 0:00:29.

# %%
data = pytry.read('data_10_to_100_neurons')

# %%
for i,d in enumerate(data):
    plot(d['x'][:,19], label=i)
    show()
    
legend()
# Out:
# //anaconda/envs/robobee/lib/python3.5/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
for i in range(10,100,10):
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# 90
